# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv('../data/spatial_merged_solid.csv')
#topics = pd.read_csv('../data/topic_output.csv')
#topic_filter = pd.read_csv('../data/categories.csv')
complaint = pd.read_csv('../data/311_complaint.csv')
insp = pd.read_csv('../DOHMH_New_York_City_Restaurant_Inspection_Results.csv')

# %%
# merge original inspection stuff with main df
df = df.merge(insp, on='CAMIS', how='inner')

# %%
# merge 311 stuff with main df
df = df.merge(complaint, on='CAMIS', how='left')

# %%
# feature selection
df = df.loc[:, ['CAMIS', # inspection data
                'GRADE_y',
                'new_grade',
                'INSPECTION DATE_y',
                'VIOLATION CODE',
                'SCORE',
                'GRADE'
                'CD', # pluto data, BBL-level (spatially merged)
                'HealthArea',
                'SanitDistr',
                'AssessTot',
                'YearAlter1',
                'YearAlter2',
                'YearBuilt',
                'NumFloors',
                'yelp_rating', # yelp data, restaurant-level
                'yelp_categories',
                'yelp_review_count',
                'stats.checkinsCount', # foursquare data, restaurant-level
                'stats.tipCount',
                'stats.usersCount',
                '311_complaint_count', # 311 food complaints, restaurant-level
                'goog_lat', # google location
                'goog_lng']]

# %%
# rename a couple weird columns post-merge
df.columns =   ['CAMIS', # inspection data
                'GRADE',
                'new_grade',
                'INSPECTION DATE',
                'VIOLATION CODE',
                'SCORE',
                'GRADE'
                'CD', # pluto data, BBL-level (spatially merged)
                'HealthArea',
                'SanitDistr',
                'AssessTot',
                'YearAlter1',
                'YearAlter2',
                'YearBuilt',
                'NumFloors',
                'yelp_rating', # yelp data, restaurant-level
                'yelp_categories',
                'yelp_review_count',
                'stats.checkinsCount', # foursquare data, restaurant-level
                'stats.tipCount',
                'stats.usersCount',
                '311_complaint_count', # 311 food complaints, restaurant-level
                'goog_lat', # google location
                'goog_lng']

# %%
# only care about the records with a y-label
df = df.loc[map(lambda g: type(g)==str, df.new_grade), :]

# %%
df.head()
# Out:
#        CAMIS           GRADE new_grade INSPECTION DATE VIOLATION CODE  SCORE  \
# 15  50063156  Not Yet Graded         C      04/13/2017            02G   29.0
# 16  50063156  Not Yet Graded         C      04/13/2017            06E   29.0
# 17  50063156  Not Yet Graded         C      04/13/2017            10B   29.0
# 18  50063156  Not Yet Graded         C      04/13/2017            04N   29.0
# 19  50063156  Not Yet Graded         C      04/13/2017            08A   29.0
#
#     GRADECD  HealthArea  SanitDistr  AssessTot    ...      NumFloors  \
# 15      NaN      3800.0         4.0   556650.0    ...            2.0
# 16      NaN      3800.0         4.0   556650.0    ...            2.0
# 17      NaN      3800.0         4.0   556650.0    ...            2.0
# 18      NaN      3800.0         4.0   556650.0    ...            2.0
# 19      NaN      3800.0         4.0   556650.0    ...            2.0
#
#     yelp_rating  yelp_categories  yelp_review_count  stats.checkinsCount  \
# 15          NaN              NaN                NaN                523.0
# 16          NaN              NaN                NaN                523.0
# 17          NaN              NaN                NaN                523.0
# 18          NaN              NaN                NaN                523.0
# 19          NaN              NaN                NaN                523.0
#
#    stats.tipCount  stats.usersCount  311_complaint_count   goog_lat   goog_lng
# 15            2.0              95.0                  2.0  40.826254 -73.921422
# 16            2.0              95.0                  2.0  40.826254 -73.921422
# 17            2.0              95.0                  2.0  40.826254 -73.921422
# 18            2.0              95.0                  2.0  40.826254 -73.921422
# 19            2.0              95.0                  2.0  40.826254 -73.921422
#
# [5 rows x 23 columns]

# %%
def clean_cat(cat):
    """
    cleans a single yelp category string
    """
    cat = cat.replace('[', '')\
    .replace(']', '')\
    .replace('u', '')\
    .replace("'", "")\
    .replace(" ", "")
    
    return cat

# %%
def get_top_categories(n):
    """
    returns a list of top n yelp categories from observed data
    """
    yelp_cats = list(df.yelp_categories)
    yelp_cats = filter(lambda cat: type(cat)==str, yelp_cats)
    yelp_cats = ','.join(yelp_cats).split(',')
    yelp_cats = map(clean_cat, yelp_cats)
    
    return map(lambda x: x[0], Counter(yelp_cats).most_common(n))

# %%
# testing top categories function
get_top_categories(10)
# Out:
# ['pizza',
#  'coffee',
#  'chinese',
#  'italian',
#  'sandwiches',
#  'breakfast_brnch',
#  'bakeries',
#  'tradamerican',
#  'newamerican',
#  'bars']

# %%
def substring(cat, cats):
    """
    checks if a string contains a substring, with error handling
    """
    try:
        return int(cat in cats)
    except TypeError:
        return 0

# %%
def category_one_hot(df, n):
    """
    appends n columns to a dataframe
    corresponding to yes/no for the 'n' most common yelp categories
    """
    for cat in get_top_categories(n):
        col_name = 'is_' + cat
        df.loc[:, col_name] = df.apply(lambda row: substring(cat, row['yelp_categories']), axis=1)
    return df

# %%
# apply category one-hots to dataframe
df = category_one_hot(df, 3)
df.head()
# Out:
#        CAMIS           GRADE new_grade INSPECTION DATE VIOLATION CODE  SCORE  \
# 15  50063156  Not Yet Graded         C      04/13/2017            02G   29.0
# 16  50063156  Not Yet Graded         C      04/13/2017            06E   29.0
# 17  50063156  Not Yet Graded         C      04/13/2017            10B   29.0
# 18  50063156  Not Yet Graded         C      04/13/2017            04N   29.0
# 19  50063156  Not Yet Graded         C      04/13/2017            08A   29.0
#
#     GRADECD  HealthArea  SanitDistr  AssessTot     ...      yelp_review_count  \
# 15      NaN      3800.0         4.0   556650.0     ...                    NaN
# 16      NaN      3800.0         4.0   556650.0     ...                    NaN
# 17      NaN      3800.0         4.0   556650.0     ...                    NaN
# 18      NaN      3800.0         4.0   556650.0     ...                    NaN
# 19      NaN      3800.0         4.0   556650.0     ...                    NaN
#
#     stats.checkinsCount  stats.tipCount  stats.usersCount  \
# 15                523.0             2.0              95.0
# 16                523.0             2.0              95.0
# 17                523.0             2.0              95.0
# 18                523.0             2.0              95.0
# 19                523.0             2.0              95.0
#
#     311_complaint_count   goog_lat   goog_lng  is_pizza  is_coffee  is_chinese
# 15                  2.0  40.826254 -73.921422         0          0           0
# 16                  2.0  40.826254 -73.921422         0          0           0
# 17                  2.0  40.826254 -73.921422         0          0           0
# 18                  2.0  40.826254 -73.921422         0          0           0
# 19                  2.0  40.826254 -73.921422         0          0           0
#
# [5 rows x 26 columns]
